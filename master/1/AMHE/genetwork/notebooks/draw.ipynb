# %%
import sys
from numbers import Real

import matplotlib.pyplot as plt
import networkx as nx
from genetwork.networks import SndlibNetworkXMLParser

# %%
parser = SndlibNetworkXMLParser[str, Real]()

# %%
with open("data/polska.xml") as n:
    network = parser.parse(n)

# %%
plt.figure(figsize=(10, 10))
nx.draw(network.graph, with_labels=True)
plt.show()

# %%
with open("data/germany50.xml") as n:
    network = parser.parse(n)

# %%
plt.figure(figsize=(10, 10))
nx.draw(network.graph, with_labels=True)
plt.show()
